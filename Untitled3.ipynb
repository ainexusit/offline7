# %%
import requests

# %%
data = requests.get("https://raw.githubusercontent.com/RIZWAN-VY/HR_Data_Analytics_and_Visualization/refs/heads/master/HR_Employee_data_kaggle.csv")

# %%
import json
data.content
# Out:
# b"Name,Gender,Department,Annual Salary,Location,Rating,Distance to Office,Age,Tenure in Company\nAarti Panchal,Female,CEO,10000000,Mumbai,Very Good,25,31,10.4\nAastha Behl,Female,Sales,880500,Bengaluru,Very Good,7,43,18.2\nAbhinaw Sinha,Male,Engineering,682200,Bengaluru,Good,15,28,6.6\nAbhishek Dabb,Male,Legal,563700,New Delhi,Very Good,5,39,13.3\nAbhishek Kumar Preetam,Male,Support,1070900,New Delhi,Poor,10,26,4.8\nAddi Studdeard,Female,Support,1084500,Mumbai,Poor,6,38,6.7\nAddia Penwright,Male,Human Resources,411600,Bengaluru,Average,7,34,1.9\nAddy Pimblett,Male,Legal,1090000,Mumbai,Very Good,7,41,9.3\nAdesh Doifode,Male,Support,430200,New Delhi,Average,9,37,8.3\nAdey Ryal,Female,Business Development,378000,Bengaluru,Average,21,32,7.1\nAdi Seawright,Female,Sales,883800,New Delhi,Average,9,33,10.7\nAditi Chauhan,Female,Product Management,844200,Mumbai,Average,25,35,13.4\nAditi Rakesh Trivedi,Female,Legal,1017600,Mumbai,Good,19,30,1.3\nAditi Ramesh Karle,Female,Sales,1107800,Mumbai,P
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(data.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11884\2750564930.py in ?()
# ----> 1 pd.DataFrame(data.content)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
