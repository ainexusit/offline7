# %%
import json

with open("eee.json") as fp:
    data = json.load(fp)
    print(data['employees']['employee'])
# Out:
# [{'id': '1', 'firstName': 'Tom', 'lastName': 'Cruise'}, {'id': '2', 'firstName': 'Maria', 'lastName': 'Sharapova'}, {'id': '3', 'firstName': 'James', 'lastName': 'Bond'}]

# %%
import pandas as pd

# %%
pd.DataFrame(data['employees']['employee'])
# Out:
#   id firstName   lastName
# 0  1       Tom     Cruise
# 1  2     Maria  Sharapova
# 2  3     James       Bond

# %%
import requests

# %%
data = requests.get("https://api.sampleapis.com/coffee/hot")

# %%
temp = json.loads(data.content)

# %%
# Out:
# list

# %%
pd.DataFrame(temp)
# Out:
#               title                                        description  \
# 0         Americano  Med en liknande smak som svart kaffe består am...
# 1          Espresso  Ett espressoskott kan serveras ensamt eller an...
# 2             Mocha  För alla chokladälskare där ute kommer ni att ...
# 3     Hot Chocolate  Under kalla vinterdagar får en kopp varm chokl...
# 4        Chai Latte  Om du letar efter en smakfull varm dryck mitt ...
# 5      Matcha Latte  Matcha latte är en grön, hälsosam kaffedryck m...
# 6     Seasonal Brew  Säsongs kaffe med olika smaktoner som karamell...
# 7          Svart Te  Svart te föddes i Kina. Det är tillverkat av b...
# 8           Islatte  Iced latte är en kyld kaffedryck som görs geno...
# 9     Islatte Mocha  Iced latte Mocha är en kombination av latte oc...
# 10  Frapino Caramel  Det är en blandad eller bättre sagt skakad kaf...
# 11    Frapino Mocka  Ännu en berömd och utsökt kall dryck för dem s...
# ...
